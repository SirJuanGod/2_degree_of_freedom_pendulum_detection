# %% [markdown]
# # Configuracion eh instalacion de librerias

# %%
# %pip install onshape-to-robot
# Out:
# Collecting onshape-to-robot
#   Using cached onshape_to_robot-1.8.2.tar.gz (46 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: numpy in c:\Users\juane\miniconda3\envs\yolo\Lib\site-packages (from onshape-to-robot) (2.4.4)
# Requirement already satisfied: requests in c:\Users\juane\miniconda3\envs\yolo\Lib\site-packages (from onshape-to-robot) (2.33.1)
# Collecting commentjson (from onshape-to-robot)
#   Using cached commentjson-0.9.0.tar.gz (8.7 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: colorama>=0.4.6 in c:\Users\juane\miniconda3\envs\yolo\Lib\site-packages (from onshape-to-robot) (0.4.6)
# Collecting numpy-stl (from onshape-to-robot)
#   Using cached numpy_stl-3.2.0-py3-none-any.whl.metadata (18 kB)
# Collecting transforms3d (from onshape-to-robot)
#   Using cached transforms3d-0.4.2-py3-none-any.whl.metadata (2.8 kB)
# Collecting python-dotenv (from onshape-to-robot)
#   Using cached python_dotenv-1.2.2-py3-none-any.whl.metadata (27 kB)
# Collecting lark-parser<0.8.0,>=0.7.1 (from commentjson->onshape-to-robot)
#   Using cached lark-parser-0.7.8.tar.gz (276 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting python-utils>=3.4.5 (from numpy-stl->onshape-to-robot)
#   Using cached python_utils-3.9.1-py2.py3-none-any.whl.metadata (9.8 kB)
# Requirement already satisfied: typing_extensions>3.10.0.2 in c:\Users\juane\miniconda3\envs\yolo\Lib\site-packages (from python-utils>=3.4.5->numpy-stl->onshape-to-robot) (4.15.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\Users\juane\miniconda3\envs\yolo\Lib\site-packages (from requests->onshape-to-robot) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\Users\juane\miniconda3\envs\yolo\Lib\site-packages (from requests->onshape-to-robot) (3.13)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\Users\juane\miniconda3\envs\yolo\Lib\site-packages (from requests->onshape-to-robot) (2.6.3)
# Requirement already satisfied: certifi>=2023.5.7 in c:\Users\juane\miniconda3\envs\yolo\Lib\site-packages (from requests->onshape-to-robot) (2026.4.22)
# Using cached numpy_stl-3.2.0-py3-none-any.whl (20 kB)
# Using cached python_utils-3.9.1-py2.py3-none-any.whl (32 kB)
# Using cached python_dotenv-1.2.2-py3-none-any.whl (22 kB)
# Using cached transforms3d-0.4.2-py3-none-any.whl (1.4 MB)
# Building wheels for collected packages: onshape-to-robot, commentjson, lark-parser
#   Building wheel for onshape-to-robot (pyproject.toml): started
#   Building wheel for onshape-to-robot (pyproject.toml): finished with status 'done'
#   Created wheel for onshape-to-robot: filename=onshape_to_robot-1.8.2-py3-none-any.whl size=63790 sha256=e366d07f8104d81b234024907cf456578f402938fa92ec265177f68e8dee9a8d
#   Stored in directory: c:\users\juane\appdata\local\pip\cache\wheels\29\40\76\a56a7672ad94aba3966f4fd7db19b283084015113ca131dc43
#   Building wheel for commentjson (pyproject.toml): started
#   Building wheel for commentjson (pyproject.toml): finished with status 'done'
#   Created wheel for commentjson: filename=commentjson-0.9.0-py3-none-any.whl size=12177 sha256=90f093c3ce40e3cac23d6ee4a266a0703020e2402ab5f31079511d1f83d7e64b
#   Stored in directory: c:\users\juane\appdata\local\pip\cache\wheels\f2\cb\58\77f1f0b3f5fa6eb3335cb0cb73de4d4bef93489dc3a3373ae8
#   Building wheel for lark-parser (pyproject.toml): started
#   Building wheel for lark-parser (pyproject.toml): finished with status 'done'
#   Created wheel for lark-parser: filename=lark_parser-0.7.8-py2.py3-none-any.whl size=62617 sha256=50d7af1d66394717f0f0974e5c7ec19fd1861436f945d0f87e23416162d963d0
#   Stored in directory: c:\users\juane\appdata\local\pip\cache\wheels\6c\c7\01\d277a7a673ffc81a1e71e816c2e5bc5f1602f9e8192c25d21c
# Successfully built onshape-to-robot commentjson lark-parser
# Installing collected packages: lark-parser, transforms3d, python-utils, python-dotenv, commentjson, numpy-stl, onshape-to-robot
#
#    ---------------------------------------- 0/7 [lark-parser]
#    ----- ---------------------------------- 1/7 [transforms3d]
#    ---------------------- ----------------- 4/7 [commentjson]
#    ---------------------------------- ----- 6/7 [onshape-to-robot]
#    ---------------------------------------- 7/7 [onshape-to-robot]
#
# Successfully installed commentjson-0.9.0 lark-parser-0.7.8 numpy-stl-3.2.0 onshape-to-robot-1.8.2 python-dotenv-1.2.2 python-utils-3.9.1 transforms3d-0.4.2
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# clave acesso: on_uJs33YsaP2uDgDvT7I7Lk
# clave secreta: QV7lUVDkZpj4Z7CQdQzv5cM45qDhCbmZFdLWmWmJ5jzWThMd

# %%
import os 

os.environ['ONSHAPE_API'] = 'https://cad.onshape.com'
os.environ['ONSHAPE_ACCESS_KEY'] = 'on_uJs33YsaP2uDgDvT7I7Lk'
os.environ['ONSHAPE_SECRET_KEY'] = 'QV7lUVDkZpj4Z7CQdQzv5cM45qDhCbmZFdLWmWmJ5jzWThMd'

# %%
# %mkdir -p model
# %echo model/config.json

# %%
# !ping cad.onshape.com

# %%
# !onshape-to-robot model
# Out:
# * onshape-to-robot version 1.8.2
# * Using configuration workspace ID dfb17eb74f41cf60494f9208 ...
# * Using configuration element ID 42dc8a690f23db7f3abfba36 ...
# * Retrieving assembly with id 42dc8a690f23db7f3abfba36
# WARNING: joint dof_center of type revolute has no limits
# + Found DOF: center (revolute)
# WARNING: joint dof_joint of type revolute has no limits
# + Found DOF: joint (revolute)
# + Found DOF: joint_2 (fixed)
# * Found total 3 degrees of freedom
# * Found 1 root nodes:
#   - Part 1 <1>
#
# + Adding part Part 1 <1>
# + Adding part Part 1 <1>
# WARNING: Parts with same name "part_1", incrementing STL name to "part_1__2"
# + Adding part Part 1 <4>
# WARNING: Parts with same name "part_1", incrementing STL name to "part_1__3"
# + Adding part Part 1 <2>
# WARNING: Parts with same name "part_1", incrementing STL name to "part_1__4"
# + Adding part Part 1 <3>
# + Adding part Part 1 <5>
# WARNING: Parts with same name "part_1", incrementing STL name to "part_1__5"
# * Writing pendulo.xml
# * Writing scene.xml

# %%
# %pip install mujoco -q

# %%
import mujoco
import mujoco.viewer

model = mujoco.MjModel.from_xml_path("model/scene.xml")
data = mujoco.MjData(model)

with mujoco.viewer.launch_passive(model, data) as viewer:
    while viewer.is_running():
        mujoco.mj_step(model, data)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 9
#       7 with mujoco.viewer.launch_passive(model, data) as viewer:
#       8     while viewer.is_running():
# ----> 9         mujoco.mj_step(model, data)
#
# KeyboardInterrupt:

# %% [markdown]
# # Verificacion Cuda

# %%
import torch

print("CUDA disponible:", torch.cuda.is_available())
if torch.cuda.is_available():
    print("GPU:", torch.cuda.get_device_name(0))

# %%
import taichi as ti

for arch in [ti.cpu, ti.vulkan, ti.opengl]:
    try:
        ti.init(arch=arch)
        print(f"{arch} disponible")
    except Exception as e:
        print(f"{arch} NO disponible:", e)

# %%
import taichi as ti
ti.init(arch=ti.vulkan)
